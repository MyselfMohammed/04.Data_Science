# %% [markdown]
# 1 Justification or answer summary needed for every question
#
# 1.1 Download the dataset from here(Click Here)

# %%
#importing Library - pandas and assigning into a New Variable - pd
import pandas as pd

# %%
#Calling an Existing Function .read_csv (With Parameter as input) from Library - pandas
#Purpose of function - To Read Dataset.CSV
#Assigning into a New Variable - dataset

dataset=pd.read_csv("PrePlacement.csv")

#Calling an Existing Variable - dataset for visibility of Dataset Taken 
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       0
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000
# ..         ...    ...      ...            ...    ...         ...     ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       0
#
# [215 rows x 15 columns]

# %% [markdown]
# 1.2 1) Replace the NaN values with correct value. And justify why you have
# chosen the same.

# %%
#Creating a Function (With Dataset as Parameter) for the Above Logics Applied with Return Statements of Created List(s) - quan, qual

def quanQual(dataset):
    
    quan=[]
    qual=[]
    
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
#Calling out the Created function - quanQual(With Dataset as Parameter) to verify the Seperated Column Names
quanQual(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
#Assigning the Created function - quanQual(With Dataset as Parameter) into Two New Variable(s) - quan, qual since it returns Two Outputs
quan,qual = quanQual(dataset)
quan, qual
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
#Calling an Existing Function .describe() from Library - pandas
#Purpose of function - To Describe Count, Mean, Standard Deviation, Min.Value, 
#Percentile (25%, 50%, 75%) and Max.Value of Quantitative Column Dataset.CSV

dataset.describe() #Here, Median, Mode are Missing. So we need to create our own Function
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.334744   66.358558   72.100558   62.278186
# std     62.209324   10.827205   10.586016    7.321524   13.275956    5.833385
# min      1.000000   40.890000   42.750000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   91.150000   88.500000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   197615.116279
# std    150305.844169
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    706250.000000

# %%
#Calling an Existing Function .DataFrame() from Library - pandas and Assigning into New Variable - descriptive
#Purpose of function - To Create a Table in Python Notebook

descriptive = pd.DataFrame() #The Keyword - DataFrame Will create a Table
descriptive #The Output is Just a _ Because we did not declare any Index and Column Name(s)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Calling an Existing Function .DataFrame (With Index and Columns Names) from Library - pandas and Assigning into Existing Variable - descriptive
#Purpose of function - To Create a Table in Python Notebook

descriptive = pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
#To Automate the "Mean","Median","Mode" to be filled in Table automatically

for columnName in quan:
    descriptive[columnName]["Mean"] = dataset[columnName] = 0
    descriptive[columnName]["Median"] = dataset[columnName] = 0
    descriptive[columnName]["Mode"] = dataset[columnName] = 0  
descriptive

# Here NaN has been replaced with Zero for Respective Columns

# Reason of Replacing NaN Values  :

# Condition Before Creating any ML Model is that Before Creating any ML Model, None of any columns should Not be "Null" Or "NaN"
# Hence, We have replaced the NaN with Zero as of Now.
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean       0     0     0        0       0     0      0
# Median     0     0     0        0       0     0      0
# Mode       0     0     0        0       0     0      0

# %% [markdown]
# 1.3 2) How many of them are not placed?

# %%
# Writing a Query to retrive Only the Column - status for Condition - Not Placed and assigning it to New Variable - notPlaced
notPlaced = dataset[dataset["status"]=='Not Placed']
notPlaced
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        0      M      0  Central      0  Central   Science         0
# 5        0      M      0   Others      0   Others   Science         0
# 6        0      F      0   Others      0   Others  Commerce         0
# 9        0      M      0  Central      0  Central  Commerce         0
# 12       0      F      0  Central      0   Others   Science         0
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198      0      F      0  Central      0  Central  Commerce         0
# 201      0      M      0  Central      0   Others   Science         0
# 206      0      M      0  Central      0  Central   Science         0
# 208      0      F      0  Central      0   Others   Science         0
# 214      0      M      0  Central      0   Others   Science         0
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# 3     Sci&Tech     No        0         Mkt&HR      0  Not Placed       0
# 5     Sci&Tech    Yes        0        Mkt&Fin      0  Not Placed       0
# 6    Comm&Mgmt     No        0        Mkt&Fin      0  Not Placed       0
# 9    Comm&Mgmt     No        0        Mkt&Fin      0  Not Placed       0
# 12   Comm&Mgmt     No        0         Mkt&HR      0  Not Placed       0
# ..         ...    ...      ...            ...    ...         ...     ...
# 198     Others     No        0         Mkt&HR      0  Not Placed       0
# 201  Comm&Mgmt     No        0         Mkt&HR      0  Not Placed       0
# 206  Comm&Mgmt     No        0        Mkt&Fin      0  Not Placed       0
# 208  Comm&Mgmt     No        0         Mkt&HR      0  Not Placed       0
# 214  Comm&Mgmt     No        0         Mkt&HR      0  Not Placed       0
#
# [67 rows x 15 columns]

# %%
print("Total No. of Candidates Not Placed are", len(notPlaced))
# Out:
# Total No. of Candidates Not Placed are 67

# %% [markdown]
# 1.4 3) Find the reason for non placement from the dataset?

# %%
# Filtering out the whole dataset according to their Status (Placed and Not Placed) and assigning them into Two New Variables
placed = dataset[dataset["status"] == "Placed"]
not_placed = dataset[dataset["status"] == "Not Placed"]

print("Total No. of Candidates Placed are", len(placed))
print("Total No. of Candidates Not Placed are", len(not_placed))
# Out:
# Total No. of Candidates Placed are 148
# Total No. of Candidates Not Placed are 67

# %%
# Calculate the average scores for placed and not placed students for Required Columns
mark_Comparison = pd.DataFrame({
    "Placed": placed[["ssc_p", "hsc_p", "degree_p", "mba_p", "etest_p"]].mean(),
    "Not Placed": not_placed[["ssc_p", "hsc_p", "degree_p", "mba_p", "etest_p"]].mean()  
})

# Display comparison table
mark_Comparison
# Out:
#           Placed  Not Placed
# ssc_p        0.0         0.0
# hsc_p        0.0         0.0
# degree_p     0.0         0.0
# mba_p        0.0         0.0
# etest_p      0.0         0.0

# %%
print(dataset[["ssc_p", "hsc_p", "degree_p", "mba_p", "etest_p"]].dtypes)
# Out:
# ssc_p       int64
# hsc_p       int64
# degree_p    int64
# mba_p       int64
# etest_p     int64
# dtype: object

# %%
#Comparing Key Columns with Graphs for Visualisation

#importing Library - matplotlib.pyplot and assigning into a New Variable - plt
import matplotlib.pyplot as plt

for column in ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p']:
    plt.figure(figsize=(8, 4)) 
    plt.hist(not_placed[column], bins=10, alpha=0.7, label='Non-Placed')
    plt.hist(dataset[column], bins=10, alpha=0.7, label='Overall')
    plt.title(f'Comparison of {column} for Non-Placed vs Overall')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()
    
# plt.figure() initializes a new figure for each column.
# figsize=(8, 4) specifies the size of the figure in inches (width: 8, height: 4).
# bins=10 means the Entire Dataset is divided into 10 Bars (bins) for visualization.
# alpha=0.7 sets the transparency of the bars so overlapping histograms can be seen more clearly.
# label='Non-Placed' and label='Overall' adds a label for this dataset (used later for the legend).
# plt.title() sets the title of the plot.
# f'Comparison of {column} for Non-Placed vs Overall' dynamically generates a title based on the current column
# labels the X-axis with the name of the current column
# labels the Y-axis with "Frequency", indicating how often values occur in each bin.
# plt.legend() displays the labels ("Non-Placed" and "Overall") on Top of the Bar
# plt.show() Displays the plot on the screen for the current column.

# %%
# Performing Correlation Analysis

#Calling an Existing Function .corr() from Library - pandas
#Performing Correlation Analysis for Category - Placed and assigning it to New Variable - correlationMatrixOfPlaced
#Performing Correlation Analysis for Category - Not Placed and assigning it to New Variable - correlationMatrixOfNotPlaced
#Purpose of function To know the Correlation between Quantitative Columns
#Drop First Row (sl_no) and First Column (sl_no) from Output Using Method .iloc[1:, 1:]

correlationMatrixOfPlaced = placed.corr().iloc[1:, 1:]
correlationMatrixOfNotPlaced = not_placed.corr().iloc[1:, 1:]

print("Correlation Matrix for Placed Students:", "\n", correlationMatrixOfPlaced,"\n") 
print("Correlation Matrix for Non-Placed Students:", "\n", correlationMatrixOfNotPlaced)
# Out:
# Correlation Matrix for Placed Students:
#            ssc_p  hsc_p  degree_p  etest_p  mba_p  salary
# ssc_p       NaN    NaN       NaN      NaN    NaN     NaN
# hsc_p       NaN    NaN       NaN      NaN    NaN     NaN
# degree_p    NaN    NaN       NaN      NaN    NaN     NaN
# etest_p     NaN    NaN       NaN      NaN    NaN     NaN
# mba_p       NaN    NaN       NaN      NaN    NaN     NaN
# salary      NaN    NaN       NaN      NaN    NaN     NaN
#
# Correlation Matrix for Non-Placed Students:
#            ssc_p  hsc_p  degree_p  etest_p  mba_p  salary
# ssc_p       NaN    NaN       NaN      NaN    NaN     NaN
# hsc_p       NaN    NaN       NaN      NaN    NaN     NaN
# degree_p    NaN    NaN       NaN      NaN    NaN     NaN
# etest_p     NaN    NaN       NaN      NaN    NaN     NaN
# mba_p       NaN    NaN       NaN      NaN    NaN     NaN
# salary      NaN    NaN       NaN      NaN    NaN     NaN

# %%
# Analyzing categorical columns

#Calling an Existing Function .DataFrame (With Index and Columns Names) from Library - pandas and Assigning into Existing Variable - other_Comparison
#Purpose of function : To Create a Table in Python Notebook

other_Comparison = pd.DataFrame(index=["Placed", "Not Placed"], 
columns=["Specialisation - Mkt&Fin","Specialisation - Mkt&HR", 
         "With Work Experience","Without Work Experience"])
other_Comparison
# Out:
#            Specialisation - Mkt&Fin Specialisation - Mkt&HR  \
# Placed                          NaN                     NaN
# Not Placed                      NaN                     NaN
#
#            With Work Experience Without Work Experience
# Placed                      NaN                     NaN
# Not Placed                  NaN                     NaN

# %%
# Filtering out the whole dataset according to their Status (Placed, Mkt&Fin and Mkt&HR ) and assigning them into New Variables
placed_MktAndFin = dataset[(dataset["status"] == "Placed") & (dataset["specialisation"] == "Mkt&Fin")]
placed_MktAndHR = dataset[(dataset["status"] == "Placed") & (dataset["specialisation"] == "Mkt&HR")]
placed_WorkEx_Yes = dataset[(dataset["status"] == "Placed") & (dataset["workex"] == "Yes")]
placed_WorkEx_No = dataset[(dataset["status"] == "Placed") & (dataset["workex"] == "No")]

# Filtering out the whole dataset according to their Status (Not Placed, Mkt&Fin and Mkt&HR ) and assigning them into New Variables
not_placed_MktAndFin = dataset[(dataset["status"] == "Not Placed") & (dataset["specialisation"] == "Mkt&Fin")]
not_placed_MktAndHR = dataset[(dataset["status"] == "Not Placed") & (dataset["specialisation"] == "Mkt&HR")]
not_placed_WorkEx_Yes = dataset[(dataset["status"] == "Not Placed") & (dataset["workex"] == "Yes")]
not_placed_WorkEx_No = dataset[(dataset["status"] == "Not Placed") & (dataset["workex"] == "No")]

# Filling out the Dataframe 
other_Comparison["Specialisation - Mkt&Fin"]["Placed"] = len(placed_MktAndFin)
other_Comparison["Specialisation - Mkt&HR"]["Placed"] = len(placed_MktAndHR)
other_Comparison["With Work Experience"]["Placed"] = len(placed_WorkEx_Yes)
other_Comparison["Without Work Experience"]["Placed"] = len(placed_WorkEx_No)

other_Comparison["Specialisation - Mkt&Fin"]["Not Placed"] = len(not_placed_MktAndFin)
other_Comparison["Specialisation - Mkt&HR"]["Not Placed"] = len(not_placed_MktAndHR)
other_Comparison["With Work Experience"]["Not Placed"] = len(not_placed_WorkEx_Yes)
other_Comparison["Without Work Experience"]["Not Placed"] = len(not_placed_WorkEx_No)

print("Specialisation of MktAndFin for Placed Students:", len(placed_MktAndFin))
print("Specialisation of Mkt&HR for Placed Students:", len(placed_MktAndHR))
print("With Work Experience for Placed Students:", len(placed_WorkEx_Yes))
print("Without Work Experience for Placed Students:", len(placed_WorkEx_No),"\n")

print("Specialisation of MktAndFin for Non-Placed Students:", len(not_placed_MktAndFin))
print("Specialisation of Mkt&HR for Non-Placed Students:", len(not_placed_MktAndHR))
print("With Work Experience for Non-Placed Students:", len(not_placed_WorkEx_Yes))
print("Without Work Experience for Non-Placed Students:", len(not_placed_WorkEx_No))

other_Comparison
# Out:
# Specialisation of MktAndFin for Placed Students: 95
# Specialisation of Mkt&HR for Placed Students: 53
# With Work Experience for Placed Students: 64
# Without Work Experience for Placed Students: 84
#
# Specialisation of MktAndFin for Non-Placed Students: 25
# Specialisation of Mkt&HR for Non-Placed Students: 42
# With Work Experience for Non-Placed Students: 10
# Without Work Experience for Non-Placed Students: 57
#            Specialisation - Mkt&Fin Specialisation - Mkt&HR  \
# Placed                           95                      53
# Not Placed                       25                      42
#
#            With Work Experience Without Work Experience
# Placed                       64                      84
# Not Placed                   10                      57

# %%
# Creating a Dynamic Function - highlight_max_min(with Parameter) to Highlight Maximum and Minimum Value of any Dataframe

def highlight_max_min(dataframe):
    """
    Highlights the maximum and minimum values in a DataFrame dynamically.

    Parameters:
    dataframe (pd.DataFrame): The DataFrame to be styled.

    Returns:
    pd.io.formats.style.Styler: Styled DataFrame with applied highlights.
    """
    styles = []  # Initialize a list to store styles for each cell

    # Iterate over the DataFrame rows and columns dynamically
    for row in dataframe.index:
        row_styles = []  # Temporary list to store styles for the current row
        for column in dataframe.columns:
            value = dataframe.loc[row, column]  # Retrieve the cell value dynamically

            # Check if the value is the maximum or minimum in the entire DataFrame
            if value == dataframe.max().max():  # Global maximum value
                row_styles.append('background-color: lightgreen')  # Highlight in green
            elif value == dataframe.min().min():  # Global minimum value
                row_styles.append('background-color: red')  # Highlight in red
            else:
                row_styles.append('background-color: white')  # Default background for other cells

        # Append the styles for the current row
        styles.append(row_styles)

    # Convert the styles into a DataFrame for styling compatibility
    def apply_styles_to_cells(df):
        return pd.DataFrame(styles, index=df.index, columns=df.columns)

    # Apply the styles dynamically to the given DataFrame
    return dataframe.style.apply(apply_styles_to_cells, axis=None)

# %%
print("The Reason for Not Placed Students may fall under this Classified Categories","\n")

print("Correlation Matrix for Non-Placed Students:", "\n", correlationMatrixOfNotPlaced)
highlight_max_min(other_Comparison)
# Out:
# The Reason for Not Placed Students may fall under this Classified Categories
#
# Correlation Matrix for Non-Placed Students:
#            ssc_p  hsc_p  degree_p  etest_p  mba_p  salary
# ssc_p       NaN    NaN       NaN      NaN    NaN     NaN
# hsc_p       NaN    NaN       NaN      NaN    NaN     NaN
# degree_p    NaN    NaN       NaN      NaN    NaN     NaN
# etest_p     NaN    NaN       NaN      NaN    NaN     NaN
# mba_p       NaN    NaN       NaN      NaN    NaN     NaN
# salary      NaN    NaN       NaN      NaN    NaN     NaN
# <style  type="text/css" >
#     #T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row0_col0 {
#             background-color:  lightgreen;
#         }    #T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row0_col1 {
#             background-color:  white;
#         }    #T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row0_col2 {
#             background-color:  white;
#         }    #T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row0_col3 {
#             background-color:  white;
#         }    #T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row1_col0 {
#             background-color:  white;
#         }    #T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row1_col1 {
#             background-color:  white;
#         }    #T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row1_col2 {
#             background-color:  red;
#         }    #T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row1_col3 {
#             background-color:  white;
#         }</style><table id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Specialisation - Mkt&Fin</th>        <th class="col_heading level0 col1" >Specialisation - Mkt&HR</th>        <th class="col_heading level0 col2" >With Work Experience</th>        <th class="col_heading level0 col3" >Without Work Experience</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98level0_row0" class="row_heading level0 row0" >Placed</th>
#                         <td id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row0_col0" class="data row0 col0" >95</td>
#                         <td id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row0_col1" class="data row0 col1" >53</td>
#                         <td id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row0_col2" class="data row0 col2" >64</td>
#                         <td id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row0_col3" class="data row0 col3" >84</td>
#             </tr>
#             <tr>
#                         <th id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98level0_row1" class="row_heading level0 row1" >Not Placed</th>
#                         <td id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row1_col0" class="data row1 col0" >25</td>
#                         <td id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row1_col1" class="data row1 col1" >42</td>
#                         <td id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row1_col2" class="data row1 col2" >10</td>
#                         <td id="T_d92be46c_13c9_11f0_8b83_9b2d5e1a8f98row1_col3" class="data row1 col3" >57</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 1.5 4) What kind of relation between salary and mba_p

# %%
#Calling an Existing Function .corr() from Library - pandas
#Purpose of function To know the Correlation between Quantitative Columns
#Drop First Row (sl_no) and First Column (sl_no) from Output Using Method .iloc[1:, 1:]

dataset.corr().iloc[1:, 1:]

# Actual Standard Values Given :
# 1.Perfect Positive Correlation (r = 1)
# 2.High Degree of Positive Correlation (r = 0.95 Or Higher)
# 3.Low Degree of Positive Correlation (r = 0.54 Or Lower)

# Values considered for Calculation :
# 1.Perfect Positive Correlation (r = 1)
# 2.High Degree of Positive Correlation (r = 0.55 Or Higher upto 0.95)
# 3.Low Degree of Positive Correlation (r = 0.54 Or Lesser)

# Column - mba_p with Column - salary is in Low Degree of Positive Correlation (From r = 0.54 Or Lesser)
# Out:
#           ssc_p  hsc_p  degree_p  etest_p  mba_p  salary
# ssc_p       NaN    NaN       NaN      NaN    NaN     NaN
# hsc_p       NaN    NaN       NaN      NaN    NaN     NaN
# degree_p    NaN    NaN       NaN      NaN    NaN     NaN
# etest_p     NaN    NaN       NaN      NaN    NaN     NaN
# mba_p       NaN    NaN       NaN      NaN    NaN     NaN
# salary      NaN    NaN       NaN      NaN    NaN     NaN

# %% [markdown]
# 1.6 5) Which specialization is getting minimum salary?

# %%
# Filtering out the whole dataset according to Specialisation and Salary
specialization_With_MinSalary = dataset[(dataset["specialisation"].notnull()) & (dataset["salary"] == dataset["salary"].min())]

# Selecting only the columns 'specialisation' and 'salary'
specialization_With_MinSalary = specialization_With_MinSalary.loc[:, ["specialisation", "salary"]]

# Display the filtered dataset with only the selected columns
print(specialization_With_MinSalary)
# Out:
#     specialisation  salary
# 0           Mkt&HR       0
# 1          Mkt&Fin       0
# 2          Mkt&Fin       0
# 3           Mkt&HR       0
# 4          Mkt&Fin       0
# ..             ...     ...
# 210        Mkt&Fin       0
# 211        Mkt&Fin       0
# 212        Mkt&Fin       0
# 213         Mkt&HR       0
# 214         Mkt&HR       0
#
# [215 rows x 2 columns]

# %%
# Group the dataset by 'specialisation' 
# Get the average salary of Specialisation First then Get the min salary each Specialisation
min_salary_specialization = dataset.groupby("specialisation")["salary"].mean().idxmin()

# Actual minimum salary value as well
min_salary_value = dataset.groupby("specialisation")["salary"].mean().min()

print(f"The specialization with the minimum average salary is '{min_salary_specialization}' with salary ₹{min_salary_value:.2f}")
# Out:
# The specialization with the minimum average salary is 'Mkt&Fin' with salary ₹0.00

# %% [markdown]
# 1.7 6) How many of them getting above 500000 salary?

# %%
# Filtering out whole dataset according to their Status (salary>500000) and assigning into New Variable - SalaryAbove500000
SalaryAbove500000 = dataset[dataset["salary"]>500000]
countOfSalaryAbove500000 = len(SalaryAbove500000)
print("Total No. of Students getting More than 500,000 :", countOfSalaryAbove500000)
# Out:
# Total No. of Students getting More than 500,000 : 0

# %% [markdown]
# 1.8 7) Test the Analysis of Variance between etest_p and mba_p at signifance level 5% (Make decision using Hypothesis Testing)

# %%
"""
Creating a Function - ANOVA_Paired_TTest_Dependent_Sample (With 4 Parameters as Input) 
to Automate the ANAVO Analysis for Paired T-Test (Dependent Sample)
"""

def ANOVA_Paired_TTest_Dependent_Sample(Categorical_Column_Name, Selection_In_Categorical_Column, Numerical_Group_01, Numerical_Group_02):
    """
    Performs a Paired T-Test (Dependent Sample) to check for significant differences
    between two conditions for the same Numerical_Group.
    
    Parameters:
        Categorical_Column_Name (str): Column name for the Numerical_Group (categorical).
        Selection_In_Categorical_Column (str): Specific Numerical_Group selection ("M" Or "F").
        Numerical_Group_01 (str): First numerical column to compare.
        Numerical_Group_02 (str): Second numerical column to compare.

    Returns:
        None: Prints the result of the hypothesis test.
    """
    
    # Importing the required function from the scipy library
    from scipy.stats import ttest_rel
    
    # Querying the dataset for the specified Numerical_Group and conditions
    Numerical_Group_01_Input = dataset[dataset[Categorical_Column_Name] == Selection_In_Categorical_Column][Numerical_Group_01]
    Numerical_Group_02_Input = dataset[dataset[Categorical_Column_Name] == Selection_In_Categorical_Column][Numerical_Group_02]

    # Calculating the Paired T-Test
    statistic, pvalue = ttest_rel(Numerical_Group_01_Input, Numerical_Group_02_Input)

    # Converting p-value to percentage
    pvalue_percentage = pvalue * 100

    # Displaying the results
    print(f"Statistic: {statistic}")
    print(f"p-value: {pvalue}")
    
    standard_pValue = 0.05
    
    # Hypothesis Testing
    if pvalue < standard_pValue :  # Compare the raw p-value (not percentage)
        print("\nResult:")
        print(f"p-value as a percentage: {pvalue_percentage:.2f}%")
        print("H0 / Null Hypothesis: There is no significant difference.")
        print("H1 / Alternate Hypothesis: There is a significant difference.")
        print("\nConclusion:", "\nRejected - H0 / Null Hypothesis since p-value < 0.05%.")
        print("Accepted - H1 / Alternate Hypothesis.")
    else:
        print("\nResult:")
        print(f"p-value as a percentage: {pvalue_percentage:.2f}%")
        print("H1 / Alternate Hypothesis: There is a significant difference.")
        print("H0 / Null Hypothesis: There is no significant difference.")
        print("\nConclusion:", "\nAccepted - H0 / Null Hypothesis since p-value >= 0.05%.")
        print("Rejected - H1 / Alternate Hypothesis.")

# %%
# Calling the Existing Function
ANOVA_Paired_TTest_Dependent_Sample("gender","M","etest_p","mba_p")
# Out:
# Statistic: nan
# p-value: nan
#
# Result:
# p-value as a percentage: nan%
# H1 / Alternate Hypothesis: There is a significant difference.
# H0 / Null Hypothesis: There is no significant difference.
#
# Conclusion:
# Accepted - H0 / Null Hypothesis since p-value >= 0.05%.
# Rejected - H1 / Alternate Hypothesis.
# C:\Anaconda\envs\AI_ML\lib\site-packages\scipy\stats\_distn_infrastructure.py:2039: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)

# %% [markdown]
# 1.9 8) Test the similarity between the degree_t (Sci & Tech) and specialisation (Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
"""
Creating a Function - ANOVA_Unpaired_TTest_Two_Independent_Sample (With 4 Parameters as Input) 
to Automate the ANAVO Analysis for Paired T-Test (Dependent Sample)
"""

def ANOVA_Unpaired_TTest_Two_Independent_Sample(
    Categorical_Column_01, Selection_In_Categorical_Column_01, 
    Categorical_Column_02, Selection_In_Categorical_Column_02,
    Numerical_Condition_01):
    """
    Performs a Unpaired T-Test (Two_Independent Sample) to check for significant differences
    between two conditions for the same Numerical_Group.
    
    Parameters:
        Categorical_Column_01 (str): First categorical column to filter (e.g., 'degree_t').
        Selection_In_Categorical_Column_01 (str): Value to match in the first categorical column (e.g., 'Sci&Tech').
        Categorical_Column_02 (str): Second categorical column to filter (e.g., 'specialisation').
        Selection_In_Categorical_Column_02 (str): Value to match in the second categorical column (e.g., 'Mkt&HR').
        Numerical_Column (str): The numerical column to test (e.g., 'salary').

    Returns:
        None: Prints the result of the hypothesis test.
    """
    
    # importing a Function - ttest_ind from Module - stats of Library - scipy 
    from scipy.stats import ttest_ind
    
    # Querying the dataset for Two Different Groups and One Numerical condition
    Categorical_Group_01_Input = dataset[(dataset[Categorical_Column_01] == Selection_In_Categorical_Column_01) &
    (dataset[Categorical_Column_02] == Selection_In_Categorical_Column_02)][Numerical_Condition_01]
    
    # Querying the dataset Otherthan Two Different Groups and One Numerical condition
    Categorical_Group_02_Input = dataset[
        ~(dataset[Categorical_Column_01] == Selection_In_Categorical_Column_01) &
    (dataset[Categorical_Column_02] == Selection_In_Categorical_Column_02)] [Numerical_Condition_01]
    
    # Calculating the Paired T-Test
    statistic, pvalue = ttest_ind(Categorical_Group_01_Input, Categorical_Group_02_Input)

    # Converting p-value to percentage
    pvalue_percentage = pvalue * 100

    # Displaying the results
    print(f"Statistic: {statistic}")
    print(f"p-value: {pvalue}")
    
    standard_pValue = 0.05
    
    # Hypothesis Testing
    if pvalue < standard_pValue :  # Compare the raw p-value (not percentage)
        print("\nResult:")
        print(f"p-value as a percentage: {pvalue_percentage:.2f}%")
        print("H0 / Null Hypothesis: There is no significant difference.")
        print("H1 / Alternate Hypothesis: There is a significant difference.")
        print("\nConclusion:", "\nRejected - H0 / Null Hypothesis since p-value < 0.05%.")
        print("Accepted - H1 / Alternate Hypothesis.")
    else:
        print("\nResult:")
        print(f"p-value as a percentage: {pvalue_percentage:.2f}%")
        print("H0 / Null Hypothesis: There is no significant difference.")
        print("H1 / Alternate Hypothesis: There is a significant difference.")
        print("\nConclusion:", "\nAccepted - H0 / Null Hypothesis since p-value >= 0.05%.")
        print("Rejected - H1 / Alternate Hypothesis.")

# %%
# Calling the Existing Function
ANOVA_Unpaired_TTest_Two_Independent_Sample("degree_t","Sci&Tech","specialisation","Mkt&HR","salary")
# Out:
# Statistic: nan
# p-value: nan
#
# Result:
# p-value as a percentage: nan%
# H0 / Null Hypothesis: There is no significant difference.
# H1 / Alternate Hypothesis: There is a significant difference.
#
# Conclusion:
# Accepted - H0 / Null Hypothesis since p-value >= 0.05%.
# Rejected - H1 / Alternate Hypothesis.

# %% [markdown]
# 1.10 9) Convert the Normal Distribution to Standard Normal Distribution for salary column

# %%
"""
※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※
𝐂𝐫𝐞𝐚𝐭𝐢𝐧𝐠 𝐚 𝐅𝐮𝐧𝐜𝐭𝐢𝐨𝐧 ➖ stdNormalDistributionGraph ❪𝐃𝐚𝐭𝐚𝐬𝐞𝐭 Column Name 𝐚𝐬 𝐏𝐚𝐫𝐚𝐦𝐞𝐭𝐞𝐫❫
𝐏𝐮𝐫𝐩𝐨𝐬𝐞 : 𝐓𝐨 𝐀𝐮𝐭𝐨𝐦𝐚𝐭𝐞 𝐭𝐨 Convert Normal Distribution To Standard Normal Distribution 
※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※
"""
def stdNormalDistributionGraph(columnNameOfDataset):
    
    """1. Importing Necessary Libraries"""

    #importing Library - seaborn and assigning into a New Variable - sb
    #seaborn is used for plotting the "Probability Distribution"
    import seaborn as sb
      
    """2. Calculating Mean and Standard Deviation for Sample (columnNameOfDataset)"""

    #Creating a New variable - Sample and assigning dataset into it
    sample = columnNameOfDataset
    sample_Mean = sample.mean()
    sample_StandardDeviation = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_Mean, sample_StandardDeviation))

    """3. Calculating Z-score for Sample (columnNameOfDataset)"""
    
    # A list of values for Sample (columnNameOfDataset) is created.
    values = [value for value in columnNameOfDataset]    
    
    # Here, Calculating Z-score for Sample (columnNameOfDataset)
    z_score = [((x-sample_Mean)/sample_StandardDeviation) for x in values]
    
    #Plotting Graph of Distance Plot Using Calculated Z-score
    sb.distplot(z_score,kde=True)

# %%
stdNormalDistributionGraph(dataset["salary"])
# Out:
# Mean=0.000, Standard Deviation=0.000
# C:\Anaconda\envs\AI_ML\lib\site-packages\ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
# C:\Anaconda\envs\AI_ML\lib\site-packages\ipykernel_launcher.py:32: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# C:\Anaconda\envs\AI_ML\lib\site-packages\seaborn\distributions.py:2479: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Anaconda\envs\AI_ML\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Anaconda\envs\AI_ML\lib\site-packages\numpy\lib\histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# 1.11 10) What is the probability Density Function of the salary range from 700000 to 900000?

# %%
"""
※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※
𝐂𝐫𝐞𝐚𝐭𝐢𝐧𝐠 𝐚 𝐅𝐮𝐧𝐜𝐭𝐢𝐨𝐧 ➖ 𝐠𝐞𝐭_𝐩𝐝𝐟_𝐩𝐫𝐨𝐛𝐚𝐛𝐢𝐥𝐢𝐭𝐲 ❪𝐃𝐚𝐭𝐚𝐬𝐞𝐭 Column Name 𝐚𝐬 𝐏𝐚𝐫𝐚𝐦𝐞𝐭𝐞𝐫❫
𝐏𝐮𝐫𝐩𝐨𝐬𝐞 : 𝐓𝐨 𝐀𝐮𝐭𝐨𝐦𝐚𝐭𝐞 𝐭𝐨 𝐤𝐧𝐨𝐰 𝐄𝐱𝐢𝐬𝐭𝐢𝐧𝐠 𝐏𝐞𝐫𝐜𝐞𝐧𝐭𝐚𝐠𝐞 𝐰𝐢𝐭𝐡𝐢𝐧 𝐭𝐡𝐞 𝐆𝐢𝐯𝐞𝐧 𝐒𝐭𝐚𝐫𝐭 𝐚𝐧𝐝 𝐄𝐧𝐝 𝐑𝐚𝐧𝐠𝐞
※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※※
"""

def get_pdf_probability (columnNameOfDataset,startRange,endRange):

    """1. Importing Necessary Libraries"""

    #importing a module - pyplot from Library - matplotlib
    #pyplot is used for plotting Graphs
    from matplotlib import pyplot
    
    #importing a Class - norm from module - stats of Library - scipy 
    #norm helps to define the "Normal Distribution"
    from scipy.stats import norm 
    
    #importing Library - seaborn and assigning into a New Variable - sb
    #seaborn is used for plotting the "Probability Distribution"
    import seaborn as sb
    
    """2. Plotting the Data Distribution"""  
    
    #It Plots a "Histogram" of the dataset with "Kernel Density Estimation (KDE)"
    #Color of "Kernel Density Estimation (KDE)" will be "Blue"
    #Color of "Histogram Bars" will be "Yellow"
    data_distrubion = sb.distplot(columnNameOfDataset, kde=True, kde_kws={'color':'Blue'}, color='gold')
    pyplot.axvline(startRange,color='Green')
    pyplot.axvline(endRange,color='Red')
    
    """3. Calculating Mean and Standard Deviation for Sample (Dataset)"""

    #Creating a New variable - Sample and assigning dataset into it
    sample = columnNameOfDataset
    sample_Mean = sample.mean()
    sample_StandardDeviation = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_Mean, sample_StandardDeviation))

    """4. Defining the Normal Distribution"""
    
    # Normal distribution (dist) is calculated using the pre-calculated mean and standard deviation
    norm_dist = norm(sample_Mean, sample_StandardDeviation)
    
    """5. Calculating Probability for the Given Range"""
    
    # A list of values between startrange and endrange is created.
    values = [value for value in range(startRange,endRange)]    
    
    # The Probability Density Function (PDF) is Calculated for each value.
    probabilities = [norm_dist.pdf(value) for value in values] 

    # Summing all the Calculated Probabilities
    summed_probabilities = sum(probabilities)
    
    #Converting into Percentage and printing the same
    probability_Percentage = (summed_probabilities * 100)
    print(f"Percentage of Area between the given Range ({startRange},{endRange}) : {probability_Percentage:.2f} %")
    
    # Finally, the function Ends by returning the summed probability.
    return probability_Percentage

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Anaconda\envs\AI_ML\lib\site-packages\ipykernel_launcher.py:29: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# C:\Anaconda\envs\AI_ML\lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Anaconda\envs\AI_ML\lib\site-packages\scipy\stats\_distn_infrastructure.py:1870: RuntimeWarning: divide by zero encountered in double_scalars
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# Mean=0.000, Standard Deviation=0.000
# Percentage of Area between the given Range (700000,900000) : nan %
# nan

# %% [markdown]
# 1.12 11) Test the similarity between the degree_t (Sci&Tech) with respect to etest_p and mba_p at significance level of 5%. (Make decision using Hypothesis Testing)

# %%
# Calling the Existing Function
ANOVA_Paired_TTest_Dependent_Sample("degree_t","Sci&Tech","etest_p","mba_p")
# Out:
# Statistic: nan
# p-value: nan
#
# Result:
# p-value as a percentage: nan%
# H1 / Alternate Hypothesis: There is a significant difference.
# H0 / Null Hypothesis: There is no significant difference.
#
# Conclusion:
# Accepted - H0 / Null Hypothesis since p-value >= 0.05%.
# Rejected - H1 / Alternate Hypothesis.
# C:\Anaconda\envs\AI_ML\lib\site-packages\scipy\stats\_distn_infrastructure.py:2039: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)

# %% [markdown]
# 1.13 12) Which parameter is highly correlated with salary?

# %%
#Calling an Existing Function .corr() from Library - pandas
#Purpose of function To know the Correlation between Quantitative Columns
#Drop First Row (sl_no) and First Column (sl_no) from Output Using Method .iloc[1:, 1:]
#Assigning into New Variable - correlation_dataframe

correlation_dataframe = dataset.corr().iloc[1:, 1:]

#Calling Already Created Function - highlight_max_min(With Parameter)
highlight_max_min(correlation_dataframe)
# Out:
# <style  type="text/css" >
#     #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col0 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col1 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col2 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col3 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col4 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col5 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col0 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col1 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col2 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col3 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col4 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col5 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col0 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col1 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col2 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col3 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col4 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col5 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col0 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col1 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col2 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col3 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col4 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col5 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row4_col0 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row4_col1 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row4_col2 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row4_col3 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row4_col4 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row4_col5 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row5_col0 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row5_col1 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row5_col2 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row5_col3 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row5_col4 {
#             background-color:  white;
#         }    #T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row5_col5 {
#             background-color:  white;
#         }</style><table id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ssc_p</th>        <th class="col_heading level0 col1" >hsc_p</th>        <th class="col_heading level0 col2" >degree_p</th>        <th class="col_heading level0 col3" >etest_p</th>        <th class="col_heading level0 col4" >mba_p</th>        <th class="col_heading level0 col5" >salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98level0_row0" class="row_heading level0 row0" >ssc_p</th>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col4" class="data row0 col4" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row0_col5" class="data row0 col5" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98level0_row1" class="row_heading level0 row1" >hsc_p</th>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col4" class="data row1 col4" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row1_col5" class="data row1 col5" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98level0_row2" class="row_heading level0 row2" >degree_p</th>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col0" class="data row2 col0" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col4" class="data row2 col4" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row2_col5" class="data row2 col5" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98level0_row3" class="row_heading level0 row3" >etest_p</th>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col1" class="data row3 col1" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col4" class="data row3 col4" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row3_col5" class="data row3 col5" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98level0_row4" class="row_heading level0 row4" >mba_p</th>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row4_col0" class="data row4 col0" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d5e1a8f98row4_col1" class="data row4 col1" >nan</td>
#                         <td id="T_e45d90e6_13c9_11f0_9145_9b2d

# %%
#Drop All Rows (Except-salary) and Columns (sl_no and Salary)
correlation_dataframe = dataset.corr().iloc[1:, 1:6]

#Specifying row ('salary') to be Highlighted
salary_correlation_row = correlation_dataframe.loc[['salary']] 

# Retrieving the cell value dynamically
for row in salary_correlation_row.index:        
    
    for column in salary_correlation_row.columns:
        value = salary_correlation_row.loc[row, column]  
        
        if value == salary_correlation_row.max().max(): 
            print("The Highly Correlated Parameter with Salary : ", column," - ", salary_correlation_row.max().max())
        elif value == salary_correlation_row.min().min(): 
            print("The Least Correlated Parameter with Salary : ", column," - ", salary_correlation_row.min().min())
                
#Calling Already Created Function - highlight_max_min(With Parameter)
# Highlighting the Specified Row of Dataframe
highlight_max_min(salary_correlation_row)
# Out:
# <style  type="text/css" >
#     #T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98row0_col0 {
#             background-color:  white;
#         }    #T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98row0_col1 {
#             background-color:  white;
#         }    #T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98row0_col2 {
#             background-color:  white;
#         }    #T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98row0_col3 {
#             background-color:  white;
#         }    #T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98row0_col4 {
#             background-color:  white;
#         }</style><table id="T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ssc_p</th>        <th class="col_heading level0 col1" >hsc_p</th>        <th class="col_heading level0 col2" >degree_p</th>        <th class="col_heading level0 col3" >etest_p</th>        <th class="col_heading level0 col4" >mba_p</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98level0_row0" class="row_heading level0 row0" >salary</th>
#                         <td id="T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98row0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98row0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_e46f2be2_13c9_11f0_a851_9b2d5e1a8f98row0_col4" class="data row0 col4" >nan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 1.14 13) plot any useful graph and explain it.

# %%
""" Let me take the Last Graph Plotted in 
1.11 10) What is the probability Density Function of the salary range from 700000 to 900000?
"""

get_pdf_probability(dataset["salary"],0,100000)
# Out:
# C:\Anaconda\envs\AI_ML\lib\site-packages\ipykernel_launcher.py:29: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# C:\Anaconda\envs\AI_ML\lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Anaconda\envs\AI_ML\lib\site-packages\scipy\stats\_distn_infrastructure.py:1870: RuntimeWarning: invalid value encountered in double_scalars
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# C:\Anaconda\envs\AI_ML\lib\site-packages\scipy\stats\_distn_infrastructure.py:1870: RuntimeWarning: divide by zero encountered in double_scalars
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# Mean=0.000, Standard Deviation=0.000
# Percentage of Area between the given Range (0,100000) : nan %
# nan

# %% [markdown]
# Explanation :
#
# Here, We wanted to know the PDF of Salary which ranges from 700000 to 900000 and the Graph says that
#
# > 1.Percentage of Area between the given Range (000000,100000) : 16.37 %
#
# > 2.Percentage of Area between the given Range (100000,200000) : 24.83 %
#
# > 3.Percentage of Area between the given Range (200000,300000) : 24.58 %
#
# > 4.Percentage of Area between the given Range (300000,400000) : 15.88 %
#
# > 5.Percentage of Area between the given Range (400000,500000) : 6.70 %
#
# > 6.Percentage of Area between the given Range (500000,600000) : 1.84 %
#
# > 7.Percentage of Area between the given Range (600000,700000) : 0.33 %
#
# > 8.Percentage of Area between the given Range (700000,800000) : 0.04 %
#
# > 9.Percentage of Area between the given Range (800000,900000) : 0.00 %
#
# > 10.Percentage of Area between the given Range (900000,1000000) : 0.00 %
